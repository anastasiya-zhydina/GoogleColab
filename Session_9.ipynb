# %% [markdown]
# <a href="https://colab.research.google.com/github/anastasiya-zhydina/GoogleColab/blob/main/Session_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 9

# %% [markdown]
# ## Task_1
#
# 1. Прочесть с помощью pandas файл
# california_housing_test.csv, который находится в папке
# sample_data
# 2. Посмотреть сколько в нем строк и столбцов
# 3. Определить какой тип данных имеют столбцы

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# ## Task_2
#
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000

# %%
df.isnull().sum() # количество пропусков в столбцах
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2][['median_house_value']]
# ['median_house_value'] - название столбца, значения которого выводим
# ['median_income'] - столбец по которому делаем выборку
# Out:
#       median_house_value
# 5                67000.0
# 6                67000.0
# 16              181300.0
# 28              350000.0
# 43               79300.0
# ...                  ...
# 2943             57200.0
# 2964             91300.0
# 2985            109400.0
# 2986             85400.0
# 2995            225000.0
#
# [360 rows x 1 columns]

# %%
# columns = ['longitude',	'latitude']
# df[columns]
# df.iloc[:, :2] - функция iloc первый диапазон для строк, второй для столбцов
# df.loc[:, :'latitude'] - возьмем срез доуказанного столбца, включительно
df[['longitude',	'latitude']].head(10)
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5    -119.56     36.51
# 6    -121.43     38.63
# 7    -120.65     35.48
# 8    -122.84     38.40
# 9    -118.02     34.08

# %%
# housing_median_age < 20 и median_house_value > 70000
# работают логическте амперсанты &(и) и |(или)
df[
    (df['housing_median_age']<20) &
    (df['median_house_value']>7000)
  ]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Task_3
# 1. Определить какое максимальное и минимальное
# значение median_house_value
# 2. Показать максимальное median_house_value, где
# median_income = 3.1250
# 3. Узнать какая максимальная population в зоне
# минимального значения median_house_value

# %%
df['median_house_value'].min()
# Out:
# 22500.0

# %%
df[df['median_income'] == 3.1250]['median_house_value'].max()
# Out:
# 233300.0

# %%
df[df['median_house_value'] == df['median_house_value'].min()].population.max()
# Out:
# 1230.0
